# %% [markdown]
# # Logistic Regression

# %% [markdown]
# __Logistic regression is a kind of statistical analysis that is used to predict the outcome of a dependent variable based on prior observations__

# %%
print ("Logistic Regression")
display(Image(filename = 'log.png'))
# Out:
# Logistic Regression

# %% [markdown]
# __This dataset contain the information of user in a social network & one of their client is "Tour & Travel" company , who puts adds on their website .Now they have introduce a new tour package and we are trying to built a model to see which of these user of the social network are going to by this package__.

# %%
# Importing the libraries
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd

# %%
# Importing the dataset
db = pd.read_csv("Social_Network_Ads.csv")

# %%
db.head(10)
# Out:
#     User ID  Gender  Age  EstimatedSalary  Purchased
# 0  15624510    Male   19            19000          0
# 1  15810944    Male   35            20000          0
# 2  15668575  Female   26            43000          0
# 3  15603246  Female   27            57000          0
# 4  15804002    Male   19            76000          0
# 5  15728773    Male   27            58000          0
# 6  15598044  Female   27            84000          0
# 7  15694829  Female   32           150000          1
# 8  15600575    Male   25            33000          0
# 9  15727311  Female   35            65000          0

# %%
# checking the shape of dataset
db.shape
# Out:
# (400, 5)

# %%
# checking the column of dataset
db.columns
# Out:
# Index(['User ID', 'Gender', 'Age', 'EstimatedSalary', 'Purchased'], dtype='object')

# %%
# checking the datatypes of column
db.dtypes
# Out:
# User ID             int64
# Gender             object
# Age                 int64
# EstimatedSalary     int64
# Purchased           int64
# dtype: object

# %%
# checking the missing value 
db.isnull().sum()
# Out:
# User ID            0
# Gender             0
# Age                0
# EstimatedSalary    0
# Purchased          0
# dtype: int64

# %%
# here our matrix of feature (independent variable ) will Age & EstimatedSalary
# our dependet variable will be Purchased 
# so lets first creat the two matrix X & Y
X = db.iloc[:, [2, 3]].values
y = db.iloc[:, 4].values

# %%
# Now our matrices are ready so now creat the Test & Train dataset
from sklearn.cross_validation import train_test_split
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size = 0.25, random_state = 33)
# Out:
# C:\Anaconda3\lib\site-packages\sklearn\cross_validation.py:41: DeprecationWarning: This module was deprecated in version 0.18 in favor of the model_selection module into which all the refactored classes and functions are moved. Also note that the interface of the new CV iterators are different from that of this module. This module will be removed in 0.20.
#   "This module will be removed in 0.20.", DeprecationWarning)

# %%
# once we split the dataset now its time for feature Scaling
from sklearn.preprocessing import StandardScaler
sc = StandardScaler()
X_train = sc.fit_transform(X_train)
X_test = sc.transform(X_test)
# Out:
# C:\Anaconda3\lib\site-packages\sklearn\utils\validation.py:475: DataConversionWarning: Data with input dtype int64 was converted to float64 by StandardScaler.
#   warnings.warn(msg, DataConversionWarning)

# %% [markdown]
# ## Feature Scaling
#
# - Every variable follow a different measuring scale and this creat issue with many Machine Learning model coz many machine Learning models are based on "Euclidean Distance" between two points , and "Euclidean Distance" are calculate by the cordinate of two points . So if the points are not in same scale that will create issue in the model .
#
# The three main type of feature scaling are -
#
#     a) Standardisation - In this process each observation is subtract by the mean of that variable and then divided by its Standard devation .
#     b) Normalisation - In this process each observation is subtract by the minimum value of that variable and then divided by its Range .
#     c) Mean normalization - In this process each observation is subtract by the minimum value of that variable and then divided by its Standard devation .

# %%
# Fitting Logistic Regression to the Training set
from sklearn.linear_model import LogisticRegression
classifier = LogisticRegression(random_state = 0)
classifier.fit(X_train, y_train)
# Out:
# LogisticRegression(C=1.0, class_weight=None, dual=False, fit_intercept=True,
#           intercept_scaling=1, max_iter=100, multi_class='ovr', n_jobs=1,
#           penalty='l2', random_state=0, solver='liblinear', tol=0.0001,
#           verbose=0, warm_start=False)

# %%
# Predicting the Test set results
y_pred = classifier.predict(X_test)

# %%
# Making the Confusion Matrix
from sklearn.metrics import confusion_matrix
cm = confusion_matrix(y_test, y_pred)

# %% [markdown]
# ## Confusion Matrix
#
# - a confusion matrix, also known as an error matrix,[4] is a specific table layout that allows visualization of the performance of an algorithm .

# %%
print ("Confusion Matrix")
display(Image(filename = 'Confusion.png'))
# Out:
# Confusion Matrix

# %%
print(cm)
# Out:
# [[54  7]
#  [ 8 31]]

# %%
# Visualising the Training set results
from matplotlib.colors import ListedColormap
X_set, y_set = X_train, y_train
X1, X2 = np.meshgrid(np.arange(start = X_set[:, 0].min() - 1, stop = X_set[:, 0].max() + 1, step = 0.01),
                     np.arange(start = X_set[:, 1].min() - 1, stop = X_set[:, 1].max() + 1, step = 0.01))
plt.contourf(X1, X2, classifier.predict(np.array([X1.ravel(), X2.ravel()]).T).reshape(X1.shape),
             alpha = 0.75, cmap = ListedColormap(('red', 'green')))
plt.xlim(X1.min(), X1.max())
plt.ylim(X2.min(), X2.max())
for i, j in enumerate(np.unique(y_set)):
    plt.scatter(X_set[y_set == j, 0], X_set[y_set == j, 1],
                c = ListedColormap(('red', 'green'))(i), label = j)
plt.title('Classifier (Training set)')
plt.xlabel('Age')
plt.ylabel('Estimated Salary')
plt.legend()
plt.show()

# %%
# Visualising the Test set results
from matplotlib.colors import ListedColormap
X_set, y_set = X_test, y_test
X1, X2 = np.meshgrid(np.arange(start = X_set[:, 0].min() - 1, stop = X_set[:, 0].max() + 1, step = 0.01),
                     np.arange(start = X_set[:, 1].min() - 1, stop = X_set[:, 1].max() + 1, step = 0.01))
plt.contourf(X1, X2, classifier.predict(np.array([X1.ravel(), X2.ravel()]).T).reshape(X1.shape),
             alpha = 0.75, cmap = ListedColormap(('red', 'green')))
plt.xlim(X1.min(), X1.max())
plt.ylim(X2.min(), X2.max())
for i, j in enumerate(np.unique(y_set)):
    plt.scatter(X_set[y_set == j, 0], X_set[y_set == j, 1],
                c = ListedColormap(('red', 'green'))(i), label = j)
plt.title('Logistic Regression (Test set)')
plt.xlabel('Age')
plt.ylabel('Estimated Salary')
plt.legend()
plt.show()

# %% [markdown]
# __Great so by this way we can use the othe calssification algorith also __.

# %% [markdown]
# Yes Ofcourse have a look -
#
# __K-Nearest Neighbors (K-NN)__
#
# __Decision Tree Classification__
#
# __Random Forest Classification__

# %% [markdown]
# __Thats it, Its super easy we built the model , Scikit-learn has a very good documentation , so by this we can make any  model ? thats great !__

# %% [markdown]
# yes of course , but this was an example just to show how we work with "__Scikit-learn__" library and few concept .
#
# did u get all the topic ?

# %% [markdown]
# __Not all , in this have few doubt in Confusion Matrix , In pandas with the help of "Tab & Shift Tab" I will be able to learn , I read stats in high school so its seems ok , A Data is a Data and while working on many industry I have some knoledge of data. So yes  almost you can say , Now I think I am ready for work__

# %% [markdown]
# Confusion Matrix confuse almost every one , so with time you will learn the tips and tricks of that , so when you are ready lets have a look on this real time problem .

# %% [markdown]
# https://www.kaggle.com/c/home-credit-default-risk

# %% [markdown]
# __What is it , are you insane ?__

# %% [markdown]
# What happen ?

# %% [markdown]
# __Buddy they have 8 dataset with total 200 + Column & more then 10 million rows in almost every dataset__

# %% [markdown]
# You said that you are ready to take challange .

# %% [markdown]
# __Yes I am__

# %% [markdown]
# Ok , then let's start with a Detail Discussion .

# %%
from IPython.display import Image
