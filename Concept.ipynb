# %% [markdown]
# #   DATA SCIENCE   (__Q__ & *A*)

# %% [markdown]
# __Hi , From last few days I heard a lot about "Artificial Intelligence (AI)" , what is it ?
# When I google, as usual I get confused with lots of new terms like "Machine Learning (ML)" , "Deep learning" , "Neural Network" . Then I thought it will be easy to interpret things in visual form so I checked the images section , The diagram are amazing just have a look .__

# %%
print ("Artificial Intelligence")
display(Image(filename = 'AI.png'))
print ("DataScience")
display(Image(filename = 'FourthBubble.png'))
print ("Machine Learning Algorithms")
display(Image(filename = 'machinelearningalgorithms.png'))
# Out:
# Artificial Intelligence
# DataScience
# Machine Learning Algorithms

# %% [markdown]
# __Its seems like one need superpower for doing these stuffs .
# Is there any way to understand the basic concept ?__

# %% [markdown]
# It is the most hot and complicated topic of the town, but you can undestand the topic. And for that you don't need any superpower.
#
#  Knowledge of Basic elementary Maths ,Stats and problem solving skills is enough to get started.

# %% [markdown]
# __"Mathematics & Statistics"  Are they different , "I thought Statistics is the part of Maths " ?__

# %% [markdown]
# - Yes, Ofcourse Statistics is a branch of Mathematics, but their are many definaton of Stats , have a look on few ,
#
# 1) "__Merriam-Webster__" dictionary defines statistics as "a branch of mathematics dealing with the collection, analysis, interpretation, and presentation of masses of numerical data."
#
# 2) Statistician "__Arthur Lyon Bowley__" defines statistics as "Numerical statements of facts in any department of inquiry placed in relation to each other .
#
# (Ref :- https://en.wikipedia.org/wiki/Statistics#Scope )
#
# Both the definations are true , but in second one their is no mathematic , its telling that Stats deals with "All the Subject present in Universe "

# %% [markdown]
# As we Know that, we can do research or Master degree from any Known Subject , and the research methodology always be the __Rules of STATS__ .

# %% [markdown]
# __SO when we already have "STATS & Research" , then what is the requirement of "DATA SCIENCE"__ ?

# %% [markdown]
# To overcome with the limitation, like
#
# - Earlier In a normal research 80 - 90 % of the total resources required by one step "DataCollection" and it was really painful.
# - Stats calculation is only possible with number and structure data (Table formet) .
#
# These 2 are the main drawback of "STATS & Research" .
#
# Now after the development  " world wide web " & "Soical Networking " all of a sudden we had now "__Tsunami__" of data and its growing in exponentially on daily basis.
#
# Now the problem is how to process that huge volume of data , because there are no difference between "raw data" & "garbage" , and process data is  precious than any thing .
#
#
# So to encounter these problem we develop a New Science that is Known as "__Data Science__" .
#
#
# Now as we got all the data from WEB and the Quantity is huge so now its impossible to process them with pen & paper . So "__Programing Language__" became the main tool to transform raw data into information .
#
# Now to Handle different type of Data and different type of problem. So with the help of  __Programing Languages__ people develop many algorithms using the maths models .
# Those algorithms are known as "__Machine Learning Algorithms__".

# %% [markdown]
# So coming back to topic the  "__DATA SCIENCE__",  we will cover the Topic in 4 part .
#
# - __DATA__  http://localhost:8888/notebooks/Desktop/Data_Science/Data.ipynb
#
# - __STAT__  http://localhost:8888/notebooks/Desktop/Data_Science/Statistic.ipynb
#
# - __Programming language__  http://localhost:8888/notebooks/Desktop/Data_Science/Programming_language.ipynb
#
# - __Algorithm__  http://localhost:8888/notebooks/Desktop/Data_Science/Algorithm.ipynb

# %% [markdown]
# ### Reference for images , study material & dataset.

# %% [markdown]
# https://www.slideshare.net/ILRI-Jmaru/module-4-data-analysis
#
# https://www.quora.com/What-exactly-is-a-data-structure
#
# http://fighting41love.github.io/2016/01/28/Precision%20recall%E7%AD%89%E6%8C%87%E6%A0%87%E7%9A%84%E8%AE%A1%E7%AE%97%E6%96%B9%E6%B3%95/
#
# http://sbst1103.blogspot.com/2010/08/topic-1-types-of-data-part-1.html
#
# http://www.casamagdalena.us/data-scientist-diagram.html
#
# http://www.saedsayad.com/logistic_regression.htm
#
# https://www.wikipedia.org/
#
# https://www.techopedia.com/
#
# www.kaggle.com/
#
# www.analyticsvidhya.com
#
# www.superdatascience.com
#
# https://towardsdatascience.com
#
# https://stackoverflow.com
#
# www.github.com
#
# http://scikit-learn.org/stable/documentation.html
#
# https://matplotlib.org/contents.html
#
# https://pandas.pydata.org/pandas-docs/stable/
#
# https://www.youtube.com/user/dataschool

# %%
from IPython.display import Image

# %%
from IPython.display import HTML

# %%
HTML('''<script>
code_show=true; 
function code_toggle() {
 if (code_show){
 $('div.input').hide();
 } else {
 $('div.input').show();
 }
 code_show = !code_show
} 
$( document ).ready(code_toggle);
</script>
The raw code for this IPython notebook is by default hidden for easier reading.
To toggle on/off the raw code, click <a href="javascript:code_toggle()">here</a>.''')
# Out:
# <script>
# code_show=true;
# function code_toggle() {
#  if (code_show){
#  $('div.input').hide();
#  } else {
#  $('div.input').show();
#  }
#  code_show = !code_show
# }
# $( document ).ready(code_toggle);
# </script>
# The raw code for this IPython notebook is by default hidden for easier reading.
# To toggle on/off the raw code, click <a href="javascript:code_toggle()">here</a>.
