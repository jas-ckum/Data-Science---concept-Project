# %% [markdown]
# # Machine learning - Algorithm

# %% [markdown]
# In simple langauage algorithm is a process or set of rules to be followed in calculations or other problem-solving operations .

# %%
print ("Machine Learning Algorithms")
display(Image(filename = 'r/machinelearningalgorithms.png'))
# Out:
# Machine Learning Algorithms

# %% [markdown]
# So according to above picture we  __11__ types of __Machine Learning Algorithms__  , and each type containing minimum 4 & maximum 11 (total 63) different rules , so solve different problem with different varity of data

# %% [markdown]
# __Why so many Algorithms , and do we required to usnderstand and mug up all of them ?__

# %% [markdown]
# Algorithms are based on sets of maths & business rules , every algo is functionaly different from other like
#
# Dimensionality reduction is based on the concept of 'Determinant' or "eigenvalue and eigen matrix"  in Algebra or matrix .
#
# Apriori Algorithms is based on the "Retail Managment" concept of market basket rule . etc
#
#
#
#
# and when you have so many in the list and its on continous development you can't mug up all of them so first understand the concept , and think for the utilization . that is the only way you can learn .

# %% [markdown]
# __I have heard 2 famous word in  Machine Learning__
#
#     1) Supervised learning
#
#     2) Unsupervised learning
#
# __and both of them is missing in the graph , why so ?__

# %% [markdown]
# Supervised & Unsupervised learning is not an algorithm , It is classiffication of the problem base on data that we will solve ,
#
#  A problem is Supervised learning when, In data we have target variable given , In Unsupervised we don't have target variable present in our data .
#
#  We will start with Supervised learning .

# %% [markdown]
# - In  Machine Learning Algoritm, the main concepts are the parameters. so as we will take the example we will see the parameters and triks of parameters.

# %%
from IPython.display import Image
from IPython.display import HTML
